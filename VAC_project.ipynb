# %% [markdown]
# <a href="https://colab.research.google.com/github/keyan12/vacproject/blob/main/VAC_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
from google.colab.patches import cv_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
bikes=os.listdir("/content/drive/MyDrive/VAC dataset/bikes")

# %%
cars=os.listdir("/content/drive/MyDrive/VAC dataset/Cars")

# %%
limit=10
bikes_images=[None]*limit
j=0
for i in bikes:
    if(j<limit):
        bikes_images[j]=imread("/content/drive/MyDrive/VAC dataset/bikes/"+i)
        j+=1
    else:
        break

# %%
cars_images=[None]*limit
j=0
for i in cars:
    if(j<limit):
        cars_images[j]=imread("/content/drive/MyDrive/VAC dataset/Cars/"+i)
        j+=1
    else:
        break

# %%
imshow(bikes_images[1])

# %%
imshow(cars_images[1])

# %%
bikes_gray=[None]*limit
j=0
for i in bikes:
    if(j<limit):
         bikes_gray[j]=rgb2gray(bikes_images[j])
         j+=1
    else:
         break

# %%
cars_gray=[None]*limit
j=0
for i in cars:
    if(j<limit):
        cars_gray[j]=rgb2gray(cars_images[j])
        j+=1
    else:
         break

# %%
imshow(bikes_gray[1])

# %%
imshow(cars_gray[1])

# %%
bikes_gray[2].shape

# %%
for j in range (10):
 rk=bikes_gray[j]
 bikes_gray[j]=resize(rk,(512,512))

# %%
cars_gray[1].shape
# Out:
# (234, 343)

# %%
for j in range (10):
 rk=cars_gray[j]
 cars_gray[j]=resize(rk,(512,512))

# %%
len_of_images_bikes=len(bikes_gray)
len_of_images_bikes
# Out:
# 10

# %%
len_of_images_cars=len(cars_gray)

# %%
image_size_bikes=bikes_gray[1].shape

# %%
image_size_cars=cars_gray[1].shape

# %%
image_size_bikes
# Out:
# (512, 512)

# %%
image_size_cars
# Out:
# (512, 512)

# %%
flatten_size_bikes=image_size_bikes[0]*image_size_bikes[0]

# %%
flatten_size_cars=image_size_cars[0]*image_size_cars[1]

# %%
flatten_size_bikes
# Out:
# 262144

# %%
flatten_size_cars
# Out:
# 262144

# %%
for i in range(len_of_images_bikes):
  bikes_gray[i]=np.ndarray.flatten(bikes_gray[i]).reshape(flatten_size_bikes,1)

# %%
for i in range(len_of_images_cars):
 cars_gray[i]=np.ndarray.flatten(cars_gray[i]).reshape(flatten_size_cars,1)

# %%
bikes_gray=np.dstack(bikes_gray)
bikes_gray.shape
# Out:
# (262144, 1, 10)

# %%
cars_gray=np.dstack(cars_gray)
cars_gray.shape
# Out:
# (262144, 1, 10)

# %%
bikes_gray=np.rollaxis(bikes_gray,axis=2,start=0)

# %%
cars_gray=np.rollaxis(cars_gray,axis=2,start=0)

# %%
bikes_gray.shape
# Out:
# (10, 262144, 1)

# %%
cars_gray.shape
# Out:
# (10, 262144, 1)

# %%
bikes_gray=bikes_gray.reshape(len_of_images_bikes,flatten_size_bikes)

# %%
cars_gray=cars_gray.reshape(len_of_images_cars,flatten_size_cars)

# %%
bikes_gray.shape
# Out:
# (10, 262144)

# %%
cars_gray.shape
# Out:
# (10, 262144)

# %%
bikes_data=pd.DataFrame(bikes_gray)

# %%
cars_data=pd.DataFrame(cars_gray)

# %%
bikes_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 3  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 5  0.998974  0.998974  0.998974  0.998974  0.998974  0.998506  0.995213
# 6  0.994067  0.996752  0.998586  0.994307  0.993306  0.995108  0.999959
# 7  0.996936  0.996936  0.996936  0.996936  0.996936  0.995647  0.993758
# 8  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 9  0.988909  0.990135  0.992157  0.992157  0.992157  0.992157  0.992157
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.992157  0.992157  0.992157  ...  0.992157  0.992157  0.992157  0.992157
# ...

# %%
cars_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 3  0.999935  0.999072  0.996885  0.996078  0.996078  0.996078  0.996781
# 4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992666  0.995967
# 5  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 6  0.998947  0.998947  0.997045  0.996078  0.996078  0.996078  0.995948
# 7  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 8  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 9  0.995037  0.995037  0.995037  0.995037  0.995037  0.995037  0.995037
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.992157  0.992157  0.992157  ...  0.988235  0.988235  0.988235  0.988235
# ...

# %%
bikes_data["label"]="bikes"

# %%
cars_data["label"]="cars"

# %%
bikes_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 3  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 5  0.998974  0.998974  0.998974  0.998974  0.998974  0.998506  0.995213
# 6  0.994067  0.996752  0.998586  0.994307  0.993306  0.995108  0.999959
# 7  0.996936  0.996936  0.996936  0.996936  0.996936  0.995647  0.993758
# 8  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 9  0.988909  0.990135  0.992157  0.992157  0.992157  0.992157  0.992157
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.992157  0.992157  0.992157  ...  0.992157  0.992157  0.992157  0.992157
# ...

# %%
cars_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 3  0.999935  0.999072  0.996885  0.996078  0.996078  0.996078  0.996781
# 4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992666  0.995967
# 5  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 6  0.998947  0.998947  0.997045  0.996078  0.996078  0.996078  0.995948
# 7  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 8  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 9  0.995037  0.995037  0.995037  0.995037  0.995037  0.995037  0.995037
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.992157  0.992157  0.992157  ...  0.988235  0.988235  0.988235  0.988235
# ...

# %%
vehicle=pd.concat([bikes_data,cars_data])

# %%
vehicle
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 3  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 5  0.998974  0.998974  0.998974  0.998974  0.998974  0.998506  0.995213
# 6  0.994067  0.996752  0.998586  0.994307  0.993306  0.995108  0.999959
# 7  0.996936  0.996936  0.996936  0.996936  0.996936  0.995647  0.993758
# 8  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 9  0.988909  0.990135  0.992157  0.992157  0.992157  0.992157  0.992157
# 0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# ...

# %%
from sklearn.utils import shuffle

# %%
transport_indexed=shuffle(vehicle).reset_index()

# %%
transport_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       3  0.999935  0.999072  0.996885  0.996078  0.996078  0.996078
# 1       1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2       0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 3       4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992666
# 4       4  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 5       5  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 6       2  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 7       5  0.998974  0.998974  0.998974  0.998974  0.998974  0.998506
# 8       8  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 9       1  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 10      0  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 11      2  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# ...

# %%
vehicles=transport_indexed.drop(['index'],axis=1)

# %%
vehicles
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.999935  0.999072  0.996885  0.996078  0.996078  0.996078  0.996781
# 1   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 2   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 3   0.992157  0.992157  0.992157  0.992157  0.992157  0.992666  0.995967
# 4   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 5   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 6   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 7   0.998974  0.998974  0.998974  0.998974  0.998974  0.998506  0.995213
# 8   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 9   0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 10  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157  0.992157
# 11  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# ...

# %%
vehicles.to_csv("/content/drive/MyDrive/VAC dataset/vehicles.csv")

# %%
x=vehicles.values[:,:-1]

# %%
y=vehicles.values[:,-1]

# %%
x
# Out:
# array([[0.9999353483611462, 0.9990718654557771, 0.9968849219527899, ...,
#         0.9980070114135742, 1.0, 1.0],
#        [0.9921568627450982, 0.9921568627450982, 0.9921568627450983, ...,
#         0.9921568627450983, 0.9921568627450982, 0.9921568627450982],
#        [0.9921568627450982, 0.9921568627450982, 0.9921568627450982, ...,
#         0.9921568627450982, 0.9921568627450982, 0.9921568627450982],
#        ...,
#        [0.996078431372549, 0.996078431372549, 0.996078431372549, ...,
#         0.9965340633018345, 0.9970818014705882, 0.9970818014705882],
#        [0.9950367647058823, 0.9950367647058824, 0.9950367647058824, ...,
#         0.9931985294117649, 0.9925741756663603, 0.9905267453661152],
#        [0.9921568627450982, 0.9921568627450983, 0.9921568627450982, ...,
#         0.9930951286764707, 0.9930951286764707, 0.9930951286764707]],
#       dtype=object)

# %%
y
# Out:
# array(['cars', 'cars', 'bikes', 'cars', 'bikes', 'cars', 'bikes', 'bikes',
#        'cars', 'bikes', 'cars', 'cars', 'bikes', 'bikes', 'cars', 'bikes',
#        'bikes', 'bikes', 'cars', 'cars'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf = svm.SVC()
clf.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['bikes', 'cars', 'cars', 'bikes'], dtype=object)

# %%
for i in (np.random.randint(1,3,4)):
  predicted_images = (np.reshape(x_test[i], (512,512)).astype(np.float64))
  plt.title('predicted label: {0}'. format(y_pred[i]))
  plt.imshow(predicted_images, interpolation='nearest', cmap='gray')
  plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[0, 0],
#        [2, 2]])
